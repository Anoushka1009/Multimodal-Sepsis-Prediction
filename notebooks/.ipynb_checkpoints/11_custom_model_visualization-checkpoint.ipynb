# %% [markdown]
# # 11 Custom Model Visualization
#
# This notebook visualizes the saved evaluation artifacts for the custom multimodal models. It focuses on ROC curves, PR curves, calibration, confusion matrices, and compact metric comparisons for the multimodal fusion variants.

# %% [markdown]
# ## Visualization scope
#
# - compare `early_fusion`, `late_fusion`, `gated_fusion`, and `cross_modal_attention`
# - plot ROC curves from saved evaluation CSV artifacts
# - plot precision-recall curves from saved evaluation CSV artifacts
# - inspect calibration behavior and confusion matrices
# - save reusable figure files under `figures/11_custom_model_visualization/`

# %%
import sys
from pathlib import Path

NOTEBOOK_CWD = Path.cwd().resolve()
PROJECT_ROOT = next(
    (
        candidate
        for candidate in [NOTEBOOK_CWD, *NOTEBOOK_CWD.parents]
        if (candidate / 'configs' / 'base.yaml').exists() and (candidate / 'src').is_dir()
    ),
    None,
)
if PROJECT_ROOT is None:
    raise FileNotFoundError('Could not locate the project root from the current notebook directory.')
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from src.utils.runtime import load_project_runtime

runtime = load_project_runtime(start=PROJECT_ROOT)
IN_COLAB = runtime.in_colab
PROJECT_ROOT = runtime.project_root
config = runtime.config
paths = runtime.paths

PROJECT_ROOT
# Out:
# PosixPath('/home/sra/shankari/Multimodal-Sepsis-Prediction-main')

# %%
if IN_COLAB:
    # %pip -q install pyyaml pandas numpy matplotlib scikit-learn

# %%
import matplotlib.pyplot as plt
import pandas as pd

from src.evaluation.visualization import (
    CUSTOM_MULTIMODAL_MODELS,
    plot_calibration_curves,
    plot_confusion_matrices,
    plot_metric_bars,
    plot_pr_curves,
    plot_roc_curves,
)
from src.utils.logging_utils import write_run_manifest

# %%
config['evaluation']
# Out:
# {'default_threshold': 0.5, 'calibration_bins': 10}

# %% [markdown]
# ## Load saved evaluation artifacts
#
# Notebook 08 already saved the curve tables and summary CSVs. This notebook reads those outputs directly rather than recomputing metrics.

# %%
evaluation_dir = paths['processed_data_dir'] / '08_evaluation'
prediction_dir = paths['processed_data_dir'] / '07_multimodal_models'
figure_output_dir = paths['figures_dir'] / '11_custom_model_visualization'
figure_output_dir.mkdir(parents=True, exist_ok=True)

evaluation_summary_path = evaluation_dir / 'evaluation_summary.csv'
assert evaluation_summary_path.exists(), 'Missing evaluation summary. Run 08_evaluation first.'

evaluation_df = pd.read_csv(evaluation_summary_path)
custom_eval_df = evaluation_df.loc[evaluation_df['model_name'].isin(CUSTOM_MULTIMODAL_MODELS)].copy()
assert not custom_eval_df.empty, 'No custom multimodal rows found in evaluation_summary.csv.'

available_horizons = sorted(custom_eval_df['dataset_name'].unique().tolist())
available_horizons, custom_eval_df[['dataset_name', 'model_name', 'auroc', 'auprc', 'f1']].sort_values(['dataset_name', 'model_name']).reset_index(drop=True)
# Out:
# (['horizon_12h', 'horizon_24h', 'horizon_6h'],
#     dataset_name             model_name     auroc     auprc        f1
#  0   horizon_12h  cross_modal_attention  0.618505  0.064832  0.000000
#  1   horizon_12h           early_fusion  0.783415  0.200648  0.234375
#  2   horizon_12h           gated_fusion  0.780048  0.176338  0.102389
#  3   horizon_12h            late_fusion  0.788869  0.219549  0.252525
#  4   horizon_24h  cross_modal_attention  0.602059  0.068442  0.000000
#  5   horizon_24h           early_fusion  0.754500  0.175086  0.216867
#  6   horizon_24h           gated_fusion  0.735367  0.158776  0.171206
#  7   horizon_24h            late_fusion  0.759173  0.185511  0.212219
#  8    horizon_6h  cross_modal_attention  0.619064  0.079563  0.000000
#  9    horizon_6h           early_fusion  0.799145  0.258055  0.305344
#  10   horizon_6h           gated_fusion  0.808292  0.264337  0.300000
#  11   horizon_6h            late_fusion  0.804024  0.233935  0.276481)

# %% [markdown]
# ## Select the horizon to visualize
#
# Change `dataset_name` below if you want to plot another horizon.

# %%
dataset_name = available_horizons[0]
model_names = [
    model_name
    for model_name in CUSTOM_MULTIMODAL_MODELS
    if ((custom_eval_df['dataset_name'] == dataset_name) & (custom_eval_df['model_name'] == model_name)).any()
]

dataset_name, model_names
# Out:
# ('horizon_6h',
#  ['early_fusion', 'late_fusion', 'gated_fusion', 'cross_modal_attention'])

# %% [markdown]
# ## Metric comparison

# %%
metric_fig, metric_ax = plot_metric_bars(
    evaluation_df=custom_eval_df,
    dataset_name=dataset_name,
    model_names=model_names,
)
plt.show()

# %% [markdown]
# ## ROC and precision-recall curves

# %%
roc_fig, roc_ax = plot_roc_curves(
    evaluation_df=custom_eval_df,
    evaluation_dir=evaluation_dir,
    dataset_name=dataset_name,
    model_names=model_names,
)
plt.show()

pr_fig, pr_ax = plot_pr_curves(
    evaluation_df=custom_eval_df,
    evaluation_dir=evaluation_dir,
    dataset_name=dataset_name,
    model_names=model_names,
)
plt.show()

# %% [markdown]
# ## Calibration and confusion matrices

# %%
calibration_fig, calibration_ax = plot_calibration_curves(
    evaluation_dir=evaluation_dir,
    dataset_name=dataset_name,
    model_names=model_names,
)
plt.show()

confusion_fig, confusion_axes = plot_confusion_matrices(
    prediction_dir=prediction_dir,
    dataset_name=dataset_name,
    threshold=config['evaluation']['default_threshold'],
    model_names=model_names,
)
plt.show()

# %% [markdown]
# ## Save figure files

# %%
dataset_figure_dir = figure_output_dir / dataset_name
dataset_figure_dir.mkdir(parents=True, exist_ok=True)

saved_paths = {
    'metric_comparison': str(dataset_figure_dir / 'metric_comparison.png'),
    'roc_curves': str(dataset_figure_dir / 'roc_curves.png'),
    'pr_curves': str(dataset_figure_dir / 'pr_curves.png'),
    'calibration_curves': str(dataset_figure_dir / 'calibration_curves.png'),
    'confusion_matrices': str(dataset_figure_dir / 'confusion_matrices.png'),
}

metric_fig.savefig(saved_paths['metric_comparison'], dpi=160, bbox_inches='tight')
roc_fig.savefig(saved_paths['roc_curves'], dpi=160, bbox_inches='tight')
pr_fig.savefig(saved_paths['pr_curves'], dpi=160, bbox_inches='tight')
calibration_fig.savefig(saved_paths['calibration_curves'], dpi=160, bbox_inches='tight')
confusion_fig.savefig(saved_paths['confusion_matrices'], dpi=160, bbox_inches='tight')

manifest_path = paths['manifests_dir'] / '11_custom_model_visualization_manifest.json'
write_run_manifest(
    path=manifest_path,
    stage='11_custom_model_visualization',
    config=config,
    extra={
        'dataset_name': dataset_name,
        'model_names': model_names,
        'saved_paths': saved_paths,
    },
)

saved_paths, manifest_path
# Out:
# ({'metric_comparison': '/home/sra/shankari/Multimodal-Sepsis-Prediction-main/figures/11_custom_model_visualization/horizon_6h/metric_comparison.png',
#   'roc_curves': '/home/sra/shankari/Multimodal-Sepsis-Prediction-main/figures/11_custom_model_visualization/horizon_6h/roc_curves.png',
#   'pr_curves': '/home/sra/shankari/Multimodal-Sepsis-Prediction-main/figures/11_custom_model_visualization/horizon_6h/pr_curves.png',
#   'calibration_curves': '/home/sra/shankari/Multimodal-Sepsis-Prediction-main/figures/11_custom_model_visualization/horizon_6h/calibration_curves.png',
#   'confusion_matrices': '/home/sra/shankari/Multimodal-Sepsis-Prediction-main/figures/11_custom_model_visualization/horizon_6h/confusion_matrices.png'},
#  PosixPath('/home/sra/shankari/Multimodal-Sepsis-Prediction-main/results/manifests/11_custom_model_visualization_manifest.json'))
